# %% [markdown]
# ## About Me Lab: AI Engineering, Data Analytics & Data Science
#
# In this notebook, you'll write a short introduction about yourself using Python!
#
# ### Instructions:
# - Fill in the variables below with your details.
# - Run the cell to print your introduction.
#
# ### What to Include:
# - Your name.
# - Why you're interested in AI Engineering, Data Analytics or Data Science.
# - A fun fact about yourself or a goal for this course.

# %%
# About Me
# Please fill in the following details.

name = "Daniel Fernández Fernández"
reason = "I’m an Industrial Management Engineer currently pivoting into Data Science. My background is in optimizing processes, and I’m now focusing on predictive modeling for the financial sector. I am fascinated by how AI can quantify risk and uncover hidden patterns in market data. My goal is to combine my engineering logic with Data Science tools to drive smarter, data-driven decisions in banking"
fun_fact = "My main goal for this bootcamp is to build and showcase four specialized GitHub repositories focused on financial predictive modeling. I want to demonstrate my ability to handle real-world financial datasets and deploy end-to-end data solutions"

print(f"Hi! My name is {name}. I’m excited to learn because {reason}. A fun fact about me is: {fun_fact}.")
# Out:
# Hi! My name is Daniel Fernández Fernández. I’m excited to learn because I’m an Industrial Management Engineer currently pivoting into Data Science. My background is in optimizing processes, and I’m now focusing on predictive modeling for the financial sector. I am fascinated by how AI can quantify risk and uncover hidden patterns in market data. My goal is to combine my engineering logic with Data Science tools to drive smarter, data-driven decisions in banking. A fun fact about me is: My main goal for this bootcamp is to build and showcase four specialized GitHub repositories focused on financial predictive modeling. I want to demonstrate my ability to handle real-world financial datasets and deploy end-to-end data solutions.
